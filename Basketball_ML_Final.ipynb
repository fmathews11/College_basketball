# %%
import pandas as pd,numpy as np,pickle
pd.set_option('display.max_columns', None)
from kenpompy.utils import login
import kenpompy.summary as kp
import kenpompy.misc as kpm
import basketball_functions as bb

# %%
df = bb.create_current_dataframe()
kp_df = bb.create_kp_df()
print("Done")
# Out:
# Done

# %%
bb.get_game_prediction(df,kp_df,'Louisville','Notre Dame')
# Out:
# Louisville has a 59.6% chance of winning at home against Notre Dame
# Predicted Spread is 1

# %%
kp_df
# Out:
#                    Team   AdjO   AdjD  AdjT   Luck   OppO   OppD  Season
# 0               Gonzaga  123.3   91.6  73.6  -.051  103.5  102.6    2022
# 1                Baylor  118.9   89.5  68.1  -.002  104.6   98.7    2022
# 2               Arizona  116.7   88.7  74.0  +.002  104.9  102.7    2022
# 3               Houston  118.3   90.9  65.5  -.000  103.6  102.3    2022
# 4                Auburn  117.3   90.1  70.0  -.001  106.9   99.4    2022
# ..                  ...    ...    ...   ...    ...    ...    ...     ...
# 369       Arkansas Pine   92.0  117.8  67.9  +.034  103.4  100.5    2022
# 370    Eastern Illinois   83.3  109.9  65.6  -.044  103.5  103.3    2022
# 371  Mississippi Valley   88.8  116.7  72.2  -.059  100.2  103.2    2022
# 372      Delaware State   86.2  116.7  67.3  -.021  101.0  104.3    2022
# 373               IUPUI   81.9  112.9  62.3  -.062  100.7  106.3    2022
#
# [374 rows x 8 columns]
