# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
from sklearn.model_selection import train_test_split, cross_val_score,cross_validate, GridSearchCV, KFold
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
from sklearn.metrics import classification_report, accuracy_score, mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt
from sportsreference.ncaab.teams import Teams
from sportsreference.ncaab.teams import Team
from sportsreference.ncaab.roster import Player
from tqdm import tqdm
from sportsreference.ncaab.boxscore import Boxscore
from sklearn.linear_model import LogisticRegression,LinearRegression
import xgboost as xgb
from pprint import pprint
from sklearn.preprocessing import MinMaxScaler
import shap
from scipy import stats

# %%
df = pd.read_csv("ml_df_l4.csv")
df = df.drop(columns = [df.columns[i] for i in [6,39,66,67,68,69,70,73,74]])
print("Assuring features are scaled appropriately")
for i in df.loc[:,df.columns[df.columns.str.contains('percent')]].columns:
    if df[i].max() > 1:
        df[i] = [j/100 for j in df[i]]
df.sample(5)
# Out:
# Assuring features are scaled appropriately
#        assist_percentage  block_percentage  effective_field_goal_percentage  \
# 26810              0.601             0.113                            0.516
# 22157              0.522             0.078                            0.505
# 54421              0.535             0.106                            0.516
# 19079              0.549             0.128                            0.520
# 23984              0.472             0.088                            0.481
#
#        field_goal_percentage  free_throw_attempt_rate  free_throw_percentage  \
# 26810                  0.476                    0.353                  0.701
# 22157                  0.445                    0.301                  0.759
# 54421                  0.430                    0.392                  0.743
# 19079                  0.460                    0.393                  0.704
# 23984                  0.430                    0.356                  0.735
#
#        offensive_rating  offensive_rebound_percentage  \
# 26810             111.6                         0.400
# 22157             104.4                         0.257
# 54421             107.2                         0.298
# 19079             108.4                         0.329
# 23984              99.5                         0.299
#
#        allowed_assist_percentage  allowed_block_percentage  \
# 26810                      0.524                     0.082
# 22157                      0.554                     0.076
# 54421                      0.520                     0.094
# 19079                      0.468                     0.099
# 23984                      0.607                     0.085
#
#        allowed_effective_field_goal_percentage  allowed_field_goal_percentage  \
# 26810                                    0.454                          0.398
# 22157                                    0.543                          0.468
# 54421                                    0.468                          0.412
# 19079                                    0.463                          0.401
# 23984                                    0.538                          0.466
#
#        allowed_free_throw_attempt_rate  allowed_free_throw_percentage  \
# 26810                            0.378                          0.701
# 22157                            0.314                          0.707
# 54421                            0.349                          0.665
# 19079                            0.379                          0.703
# 23984                            0.402                          0.730
#
#        allowed_offensive_rebound_percentage  allowed_steal_percentage  \
# 26810                                 0.312                     0.096
# 22157                                 0.289                     0.095
# 54421                                 0.258                     0.092
# 19079                                 0.285                     0.087
# 23984                                 0.300                     0.092
#
#        allowed_three_point_attempt_rate  \
# 26810                             0.368
# 22157                             0.381
# 54421                             0.349
# 19079                             0.383
# 23984                             0.402
#
#        allowed_three_point_field_goal_percentage  \
# 26810                                      0.300
# 22157                                      0.397
# 54421                                      0.322
# 19079                                      0.323
# 23984                                      0.361
#
#        allowed_two_point_field_goal_percentage  \
# 26810                                    0.455
# 22157                                    0.511
# 54421                                    0.460
# 19079                                    0.450
# 23984                                    0.536
#
#        allowed_total_rebound_percentage  allowed_true_shooting_percentage  \
# 26810                             0.448                             0.497
# 22157                             0.517                             0.569
# 54421                             0.468                             0.501
# 19079                             0.474                             0.506
# 23984                             0.510                             0.575
#
#        allowed_turnover_percentage  pace  simple_rating_system  \
# 26810                        0.151  69.2                 20.63
# 22157                        0.145  71.4                 -5.51
# 54421                        0.133  71.4                 15.44
# 19079                        0.189  68.3                 19.38
# 23984                        0.176  69.0                  2.09
#
#        steal_percentage  three_point_attempt_rate  \
# 26810             0.095                     0.223
# 22157             0.075                     0.323
# 54421             0.071                     0.446
# 19079             0.103                     0.335
# 23984             0.096                     0.313
#
#        three_point_field_goal_percentage  two_point_field_goal_percentage  \
# 26810                              0.358                            0.510
# 22157                              0.367                            0.483
# 54421                              0.382                            0.469
# 19079                              0.359                            0.511
# 23984                              0.326                            0.477
#
#        total_rebound_percentage  true_shooting_percentage  \
# 26810                     0.552                     0.548
# 22157                     0.483                     0.542
# 54421                     0.532                     0.557
# 19079                     0.526                     0.555
# 23984                     0.490                     0.523
#
#        turnover_percentage  win_percentage  opp_assist_percentage  \
# 26810                0.151           0.684                  0.464
# 22157                0.148           0.267                  0.521
# 54421                0.164           0.600                  0.559
# 19079                0.154           0.730                  0.557
# 23984                0.176           0.281                  0.571
#
#        opp_block_percentage  opp_effective_field_goal_percentage  \
# 26810                 0.131                                0.493
# 22157                 0.072                                0.537
# 54421                 0.077                                0.534
# 19079                 0.109                                0.575
# 23984                 0.077                                0.519
#
#        opp_field_goal_percentage  opp_free_throw_attempt_rate  \
# 26810                      0.436                        0.354
# 22157                      0.455                        0.404
# 54421                      0.453                        0.315
# 19079                      0.492                        0.270
# 23984                      0.457                        0.411
#
#        opp_free_throw_percentage  opp_offensive_rating  \
# 26810                      0.686                 108.0
# 22157                      0.771                 109.6
# 54421                      0.762                 108.5
# 19079                      0.708                 115.5
# 23984                      0.688                 109.0
#
#        opp_offensive_rebound_percentage  opp_pace  opp_simple_rating_system  \
# 26810                             0.340      64.5                     14.11
# 22157                             0.274      69.2                     -2.30
# 54421                             0.247      65.4                      8.85
# 19079                             0.293      70.2                     21.39
# 23984                             0.345      68.2                     14.80
#
#        opp_steal_percentage  opp_three_point_attempt_rate  \
# 26810                 0.059                         0.322
# 22157                 0.074                         0.456
# 54421                 0.082                         0.445
# 19079                 0.092                         0.412
# 23984                 0.088                         0.361
#
#        opp_three_point_field_goal_percentage  \
# 26810                                  0.357
# 22157                                  0.360
# 54421                                  0.367
# 19079                                  0.401
# 23984                                  0.345
#
#        opp_two_point_field_goal_percentage  opp_total_rebound_percentage  \
# 26810                                0.473                         0.523
# 22157                                0.534                         0.507
# 54421                                0.522                         0.504
# 19079                                0.556                         0.503
# 23984                                0.520                         0.544
#
#        opp_true_shooting_percentage  opp_turnover_percentage  \
# 26810                         0.526                    0.135
# 22157                         0.581                    0.164
# 54421                         0.569                    0.147
# 19079                         0.594                    0.146
# 23984                         0.552                    0.157
#
#        opp_win_percentage  opp_assist_percentage_allowed  \
# 26810               0.611                          0.515
# 22157               0.514                          0.530
# 54421               0.533                          0.503
# 19079               0.795                          0.485
# 23984               0.632                          0.550
#
#        opp_block_percentage_allowed  \
# 26810                         0.101
# 22157                         0.100
# 54421                         0.092
# 19079                         0.099
# 23984                         0.104
#
#        opp_effective_field_goal_percentage_allowed  \
# 26810                                        0.455
# 22157                                        0.536
# 54421                                        0.494
# 19079                                        0.491
# 23984                                        0.516
#
#        opp_field_goal_percentage_allowed  opp_free_throw_attempt_rate_allowed  \
# 26810                              0.403                                0.347
# 22157                              0.450                                0.260
# 54421                              0.433                                0.327
# 19079                              0.426                                0.246
# 23984                              0.450                                0.334
#
#        opp_free_throw_percentage_allowed  \
# 26810                              0.704
# 22157                              0.722
# 54421                              0.710
# 19079                              0.713
# 23984                              0.698
#
#        opp_offensive_rebound_percentage_allowed  opp_steal_percentage_allowed  \
# 26810                                     0.301                         0.082
# 22157                                     0.281                         0.096
# 54421                                     0.248                         0.077
# 19079                                     0.310                         0.079
# 23984                                     0.255                         0.093
#
#        opp_three_point_attempt_rate_allowed  \
# 26810                                 0.313
# 22157                                 0.463
# 54421                                 0.370
# 19079                                 0.391
# 23984                                 0.395
#
#        opp_three_point_field_goal_percentage_allowed  \
# 26810                                          0.330
# 22157                                          0.373
# 54421                                          0.332
# 19079                                          0.333
# 23984                                          0.334
#
#        opp_two_point_field_goal_percentage_allowed  \
# 26810                                        0.436
# 22157                                        0.517
# 54421                                        0.492
# 19079                                        0.486
# 23984                                        0.525
#
#        opp_total_rebound_percentage_allowed  \
# 26810                                 0.477
# 22157                                 0.493
# 54421                                 0.496
# 19079                                 0.497
# 23984                                 0.456
#
#        opp_true_shooting_percentage_allowed  opp_turnover_percentage_allowed  \
# 26810                                 0.495                            0.127
# 22157                                 0.561                            0.143
# 54421                                 0.528                            0.152
# 19079                                 0.519                            0.156
# 23984                                 0.546                            0.155
#
#        home  result   AdjO   AdjD  AdjT   Luck   OppO   OppD
# 26810     0       1  105.4   99.4  59.4  0.027   98.3  107.4
# 22157     0       0  104.4  110.7  69.1 -0.077  106.9  105.1
# 54421     1       1  114.0   96.9  70.7 -0.046  107.6   96.9
# 19079     1       0  113.3   90.8  66.7 -0.007  110.7  100.4
# 23984     0       0  103.5  104.5  67.7 -0.069  108.8  101.8

# %% [markdown]
# # Outlier Removal

# %%
idx_to_remove = []
for i in df.columns.tolist():
    stat,p = stats.normaltest(df[i])
    if p <= 0.05:
        zscores = stats.zscore(df[i])
        zscores = np.abs(zscores)
        idx_list = []
        for idx,i in enumerate(zscores):
            if i >=3.2:
                idx_list.append(idx)
        for i in idx_list:
            if i not in idx_to_remove:
                idx_to_remove.append(i)
print("Identified {} outliers to remove".format(len(idx_to_remove)))
df2 = df.drop(idx_to_remove,axis = 0)

X = df2.drop('result',1)
y = df2.result
X_train,X_test,y_train,y_test = train_test_split(X,y,stratify = y)
# Out:
# Identified 5457 outliers to remove
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
clf = RandomForestClassifier(n_estimators = 500,n_jobs = -1,max_depth = 4)
clf.fit(X_train,y_train)
print(clf.score(X_train,y_train))
print(clf.score(X_test,y_test))
# Out:
# 0.7469765485329688
# 0.7408312958435208

# %%
imp_dict = {key:[] for key in ('feature','importance')}
for feat,imp in zip(X_train.columns,clf.feature_importances_):
    imp_dict['feature'].append(feat)
    imp_dict['importance'].append(imp)
    
imp_df = pd.DataFrame.from_dict(imp_dict)
imp_feats = imp_df.sort_values('importance',ascending = False).head(40)['feature'].tolist()
df2 = df.loc[:,df.columns[df.columns.isin(imp_feats)]]


corr=df2.corr()
high_corr_var=np.where(corr>0.9)
high_corr_var=[(corr.columns[x],corr.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]
for tup in high_corr_var:
    print('Removing {} as it is highly correllated with {}'.format(tup[1],tup[0]))

to_drop = []
for x,y in high_corr_var:
    if y not in to_drop:
        to_drop.append(y)

df2 = df2.drop([i for i in to_drop],axis = 1)

corr=df2.corr()
high_corr_var=np.where(corr>0.9)
high_corr_var=[(corr.columns[x],corr.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]
assert high_corr_var == []
X = df2
y = df.result
X_train,X_test,y_train,y_test = train_test_split(X,y,stratify = y)
wl_cols = X_train.columns.tolist()
X_train
# Out:
# Removing field_goal_percentage as it is highly correllated with effective_field_goal_percentage
# Removing true_shooting_percentage as it is highly correllated with effective_field_goal_percentage
# Removing true_shooting_percentage as it is highly correllated with field_goal_percentage
# Removing allowed_field_goal_percentage as it is highly correllated with allowed_effective_field_goal_percentage
# Removing allowed_true_shooting_percentage as it is highly correllated with allowed_effective_field_goal_percentage
# Removing allowed_two_point_field_goal_percentage as it is highly correllated with allowed_field_goal_percentage
# Removing allowed_true_shooting_percentage as it is highly correllated with allowed_field_goal_percentage
# Removing opp_field_goal_percentage as it is highly correllated with opp_effective_field_goal_percentage
# Removing opp_true_shooting_percentage as it is highly correllated with opp_effective_field_goal_percentage
# Removing opp_true_shooting_percentage as it is highly correllated with opp_field_goal_percentage
# Removing opp_field_goal_percentage_allowed as it is highly correllated with opp_effective_field_goal_percentage_allowed
# Removing opp_true_shooting_percentage_allowed as it is highly correllated with opp_effective_field_goal_percentage_allowed
# Removing opp_two_point_field_goal_percentage_allowed as it is highly correllated with opp_field_goal_percentage_allowed
# Removing opp_true_shooting_percentage_allowed as it is highly correllated with opp_field_goal_percentage_allowed
#        effective_field_goal_percentage  offensive_rating  \
# 25594                            0.464             100.9
# 12183                            0.470             102.4
# 40732                            0.540             108.4
# 42290                            0.500             102.3
# 14242                            0.531             115.1
# ...                                ...               ...
# 21439                            0.484              96.2
# 19178                            0.530             107.4
# 10659                            0.510             105.8
# 50181                            0.557             112.5
# 20496                            0.477              90.7
#
#        allowed_effective_field_goal_percentage  \
# 25594                                    0.521
# 12183                                    0.465
# 40732                                    0.504
# 42290                                    0.502
# 14242                                    0.496
# ...                                        ...
# 21439                                    0.485
# 19178                                    0.523
# 10659                                    0.488
# 50181                                    0.480
# 20496                                    0.510
#
#        allowed_three_point_field_goal_percentage  \
# 25594                                      0.359
# 12183                                      0.312
# 40732                                      0.359
# 42290                                      0.341
# 14242                                      0.349
# ...                                          ...
# 21439                                      0.300
# 19178                                      0.366
# 10659                                      0.318
# 50181                                      0.371
# 20496                                      0.327
#
#        allowed_total_rebound_percentage  simple_rating_system  \
# 25594                             0.494                -14.21
# 12183                             0.507                  7.69
# 40732                             0.499                 -1.75
# 42290                             0.490                  0.40
# 14242                             0.484                  6.30
# ...                                 ...                   ...
# 21439                             0.504                 -0.23
# 19178                             0.520                 -4.78
# 10659                             0.455                 15.55
# 50181                             0.468                 15.50
# 20496                             0.538                -18.31
#
#        three_point_field_goal_percentage  two_point_field_goal_percentage  \
# 25594                              0.338                            0.449
# 12183                              0.337                            0.449
# 40732                              0.372                            0.528
# 42290                              0.295                            0.531
# 14242                              0.398                            0.493
# ...                                  ...                              ...
# 21439                              0.336                            0.469
# 19178                              0.351                            0.532
# 10659                              0.333                            0.517
# 50181                              0.366                            0.561
# 20496                              0.327                            0.468
#
#        total_rebound_percentage  turnover_percentage  win_percentage  \
# 25594                     0.506                0.170           0.333
# 12183                     0.493                0.118           0.636
# 40732                     0.501                0.159           0.606
# 42290                     0.510                0.173           0.469
# 14242                     0.516                0.132           0.657
# ...                         ...                  ...             ...
# 21439                     0.496                0.181           0.500
# 19178                     0.480                0.154           0.515
# 10659                     0.545                0.160           0.643
# 50181                     0.532                0.160           0.750
# 20496                     0.462                0.202           0.212
#
#        opp_block_percentage  opp_effective_field_goal_percentage  \
# 25594                 0.068                                0.505
# 12183                 0.140                                0.516
# 40732                 0.099                                0.494
# 42290                 0.072                                0.529
# 14242                 0.066                                0.514
# ...                     ...                                  ...
# 21439                 0.111                                0.494
# 19178                 0.097                                0.505
# 10659                 0.109                                0.474
# 50181                 0.091                                0.542
# 20496                 0.085                                0.507
#
#        opp_offensive_rating  opp_simple_rating_system  \
# 25594                 103.4                     -9.20
# 12183                 109.0                     15.89
# 40732                 102.6                     -7.29
# 42290                 106.5                      2.58
# 14242                 101.2                      0.18
# ...                     ...                       ...
# 21439                 103.5                      3.12
# 19178                 101.4                     -8.79
# 10659                  97.2                      3.23
# 50181                 113.3                     18.52
# 20496                 105.2                     -6.75
#
#        opp_three_point_field_goal_percentage  \
# 25594                                  0.376
# 12183                                  0.365
# 40732                                  0.357
# 42290                                  0.357
# 14242                                  0.373
# ...                                      ...
# 21439                                  0.344
# 19178                                  0.324
# 10659                                  0.295
# 50181                                  0.375
# 20496                                  0.357
#
#        opp_two_point_field_goal_percentage  opp_total_rebound_percentage  \
# 25594                                0.469                         0.477
# 12183                                0.500                         0.511
# 40732                                0.465                         0.501
# 42290                                0.525                         0.509
# 14242                                0.488                         0.474
# ...                                    ...                           ...
# 21439                                0.483                         0.523
# 19178                                0.520                         0.473
# 10659                                0.489                         0.502
# 50181                                0.532                         0.517
# 20496                                0.496                         0.516
#
#        opp_turnover_percentage  opp_win_percentage  \
# 25594                    0.159               0.586
# 12183                    0.140               0.694
# 40732                    0.179               0.433
# 42290                    0.152               0.500
# 14242                    0.152               0.629
# ...                        ...                 ...
# 21439                    0.152               0.613
# 19178                    0.164               0.469
# 10659                    0.162               0.370
# 50181                    0.145               0.771
# 20496                    0.160               0.467
#
#        opp_effective_field_goal_percentage_allowed  \
# 25594                                        0.520
# 12183                                        0.445
# 40732                                        0.498
# 42290                                        0.513
# 14242                                        0.480
# ...                                            ...
# 21439                                        0.492
# 19178                                        0.536
# 10659                                        0.525
# 50181                                        0.483
# 20496                                        0.493
#
#        opp_steal_percentage_allowed  \
# 25594                         0.089
# 12183                         0.076
# 40732                         0.099
# 42290                         0.073
# 14242                         0.074
# ...                             ...
# 21439                         0.082
# 19178                         0.078
# 10659                         0.102
# 50181                         0.080
# 20496                         0.094
#
#        opp_three_point_field_goal_percentage_allowed  \
# 25594                                          0.362
# 12183                                          0.326
# 40732                                          0.358
# 42290                                          0.357
# 14242                                          0.329
# ...                                              ...
# 21439                                          0.329
# 19178                                          0.360
# 10659                                          0.378
# 50181                                          0.344
# 20496                                          0.344
#
#        opp_total_rebound_percentage_allowed  home   AdjO   AdjD   Luck   OppO  \
# 25594                                 0.523     1   96.4  111.4 -0.059  101.0
# 12183                                 0.489     1  107.0   98.1  0.095  107.8
# 40732                                 0.499     1  106.0  105.8  0.003  104.3
# 42290                                 0.491     0  103.4  103.0 -0.006  107.1
# 14242                                 0.526     0  116.3  106.7 -0.058  103.8
# ...                                     ...   ...    ...    ...    ...    ...
# 21439                                 0.477     1   99.6  100.4  0.057  102.8
# 19178                                 0.527     1  106.9  109.7 -0.024  100.5
# 10659                                 0.498     0  113.3   92.9  0.010  111.2
# 50181                                 0.483     1  115.6   98.8  0.112  109.8
# 20496                                 0.484     0   89.6  110.0 -0.039  102.8
#
#         OppD
# 25594  108.6
# 12183  101.5
# 40732  108.4
# 42290  102.2
# 14242  104.8
# ...      ...
# 21439  101.5
# 19178  106.8
# 10659   94.6
# 50181  100.0
# 20496  106.7
#
# [42129 rows x 30 columns]

# %%
clf = LogisticRegression(max_iter = 10000)
clf.fit(X_train,y_train)
score1 = accuracy_score(y_train,clf.predict(X_train))
score2 = accuracy_score(y_test,clf.predict(X_test))
print(score1,score2)
# Out:
# 0.7659094685371122 0.7686391796624653

# %%
df_agg = pd.DataFrame()
for t in Teams(2022):
    try:
        temp_df = t.dataframe
        df_agg = pd.concat([df_agg,temp_df],axis=0)
    except:
        pass
        
in_agg = ['Southern Methodist','Brigham Young','University of California','Illinois-Chicago','Connecticut','Massachusetts','Nevada-Las Vegas','North Carolina',
         'North Carolina-Wilmington','North Carolina State','Pittsburgh','Louisiana State','Texas Christian','Southern California','Virginia Commonwealth']
to_change = ['SMU','BYU','California','UIC','UConn','UMass','UNLV','UNC','UNC Wilmington','NC State','Pitt','LSU','TCU','USC','VCU']
rename_dict = dict(zip(in_agg,to_change))
df_agg['name'] = df_agg.name.replace(rename_dict)
df_agg.to_csv('2022_agg.csv',index = False)
df_agg
# Out:
#                           abbreviation  assist_percentage  assists  \
# ABILENE-CHRISTIAN    ABILENE-CHRISTIAN               55.5      259
# AIR-FORCE                    AIR-FORCE               60.8      186
# AKRON                            AKRON               49.0      171
# ALABAMA-AM                  ALABAMA-AM               43.3      143
# ALABAMA-BIRMINGHAM  ALABAMA-BIRMINGHAM               43.4      253
# ...                                ...                ...      ...
# WRIGHT-STATE              WRIGHT-STATE               45.6      209
# WYOMING                        WYOMING               45.4      172
# XAVIER                          XAVIER               56.4      233
# YALE                              YALE               51.4      200
# YOUNGSTOWN-STATE      YOUNGSTOWN-STATE               44.3      208
#
#                     away_losses  away_wins  block_percentage  blocks  \
# ABILENE-CHRISTIAN             4          3               5.7      28
# AIR-FORCE                     4          1              10.0      48
# AKRON                         2          1               8.1      41
# ALABAMA-AM                   10          2               8.3      40
# ALABAMA-BIRMINGHAM            2          2              12.3      84
# ...                         ...        ...               ...     ...
# WRIGHT-STATE                  4          3               7.8      53
# WYOMING                       1          4               5.6      29
# XAVIER                        1          2              13.1      79
# YALE                          4          1               8.3      42
# YOUNGSTOWN-STATE              3          4               7.7      52
#
#                    conference  conference_losses  conference_wins  \
# ABILENE-CHRISTIAN         wac                  4                2
# AIR-FORCE                 mwc                  2                1
# AKRON                     mac                  2                2
# ALABAMA-AM               swac                  2                3
# ALABAMA-BIRMINGHAM       cusa                  1                5
# ...                       ...                ...              ...
# WRIGHT-STATE          horizon                  2                6
# WYOMING                   mwc                  0                1
# XAVIER               big-east                  2                3
# YALE                      ivy                  0                1
# YOUNGSTOWN-STATE      horizon                  4                4
#
#                     defensive_rebounds  effective_field_goal_percentage  \
# ABILENE-CHRISTIAN                  386                            0.503
# AIR-FORCE                          319                            0.535
# AKRON                              369                            0.525
# ALABAMA-AM                         376                            0.410
# ALABAMA-BIRMINGHAM                 509                            0.526
# ...                                ...                              ...
# WRIGHT-STATE                       427                            0.509
# WYOMING                            399                            0.559
# XAVIER                             453                            0.515
# YALE                               397                            0.497
# YOUNGSTOWN-STATE                   472                            0.502
#
#                     field_goal_attempts  field_goal_percentage  field_goals  \
# ABILENE-CHRISTIAN                  1045                  0.447          467
# AIR-FORCE                           681                  0.449          306
# AKRON                               771                  0.453          349
# ALABAMA-AM                          879                  0.375          330
# ALABAMA-BIRMINGHAM                 1248                  0.467          583
# ...                                 ...                    ...          ...
# WRIGHT-STATE                        997                  0.459          458
# WYOMING                             792                  0.479          379
# XAVIER                              921                  0.448          413
# YALE                                908                  0.428          389
# YOUNGSTOWN-STATE                   1070                  0.439          470
#
#                     free_throw_attempt_rate  free_throw_attempts  \
# ABILENE-CHRISTIAN                     0.352                  368
# AIR-FORCE                             0.233                  159
# AKRON                                 0.415                  320
# ALABAMA-AM                            0.271                  238
# ALABAMA-BIRMINGHAM                    0.260                  324
# ...                                     ...                  ...
# WRIGHT-STATE                          0.346                  345
# WYOMING                               0.350                  277
# XAVIER                                0.391                  360
# YALE                                  0.298                  271
# YOUNGSTOWN-STATE                      0.309                  331
#
#                     free_throw_percentage  free_throws  \
# ABILENE-CHRISTIAN                   0.736          271
# AIR-FORCE                           0.667          106
# AKRON                               0.656          210
# ALABAMA-AM                          0.689          164
# ALABAMA-BIRMINGHAM                  0.701          227
# ...                                   ...          ...
# WRIGHT-STATE                        0.774          267
# WYOMING                             0.697          193
# XAVIER                              0.722          260
# YALE                                0.742          201
# YOUNGSTOWN-STATE                    0.758          251
#
#                     free_throws_per_field_goal_attempt  games_played  \
# ABILENE-CHRISTIAN                                0.259            17
# AIR-FORCE                                        0.156            14
# AKRON                                            0.272            14
# ALABAMA-AM                                       0.187            15
# ALABAMA-BIRMINGHAM                               0.182            19
# ...                                                ...           ...
# WRIGHT-STATE                                     0.268            17
# WYOMING                                          0.244            14
# XAVIER                                           0.282            16
# YALE                                             0.221            15
# YOUNGSTOWN-STATE                                 0.235            18
#
#                     home_losses  home_wins  losses  minutes_played  \
# ABILENE-CHRISTIAN             2          8       6             695
# AIR-FORCE                     1          5       6             560
# AKRON                         1          7       5             560
# ALABAMA-AM                    1          2      11             600
# ALABAMA-BIRMINGHAM            1         12       4             760
# ...                         ...        ...     ...             ...
# WRIGHT-STATE                  1          6       8             680
# WYOMING                       0          6       2             565
# XAVIER                        1         10       3             640
# YALE                          2          5       8             605
# YOUNGSTOWN-STATE              5          6       8             725
#
#                                   name net_rating  offensive_rating  \
# ABILENE-CHRISTIAN    Abilene Christian       None             104.7
# AIR-FORCE                    Air Force       None              93.7
# AKRON                            Akron       None             109.0
# ALABAMA-AM                 Alabama A&M       None              85.7
# ALABAMA-BIRMINGHAM  Alabama-Birmingham       None             111.9
# ...                                ...        ...               ...
# WRIGHT-STATE              Wright State       None             105.0
# WYOMING                        Wyoming       None             113.0
# XAVIER                          Xavier       None             107.6
# YALE                              Yale       None             101.9
# YOUNGSTOWN-STATE      Youngstown State       None             106.0
#
#                     offensive_rebound_percentage  offensive_rebounds  \
# ABILENE-CHRISTIAN                           27.1                 167
# AIR-FORCE                                   17.7                  70
# AKRON                                       32.4                 154
# ALABAMA-AM                                  26.5                 155
# ALABAMA-BIRMINGHAM                          32.2                 236
# ...                                          ...                 ...
# WRIGHT-STATE                                26.0                 149
# WYOMING                                     23.8                 107
# XAVIER                                      31.4                 174
# YALE                                        25.5                 141
# YOUNGSTOWN-STATE                            30.9                 196
#
#                     opp_assist_percentage  opp_assists  opp_block_percentage  \
# ABILENE-CHRISTIAN                    51.8          186                   8.7
# AIR-FORCE                            46.0          138                   9.4
# AKRON                                38.3          124                   6.1
# ALABAMA-AM                           62.7          227                   7.3
# ALABAMA-BIRMINGHAM                   47.7          200                   8.8
# ...                                   ...          ...                   ...
# WRIGHT-STATE                         43.4          208                   7.0
# WYOMING                              40.7          136                   6.7
# XAVIER                               47.6          181                   9.4
# YALE                                 49.2          180                  12.0
# YOUNGSTOWN-STATE                     50.7          226                   8.9
#
#                     opp_blocks  opp_defensive_rebounds  \
# ABILENE-CHRISTIAN           59                     450
# AIR-FORCE                   34                     326
# AKRON                       27                     322
# ALABAMA-AM                  48                     430
# ALABAMA-BIRMINGHAM          75                     496
# ...                        ...                     ...
# WRIGHT-STATE                47                     424
# WYOMING                     29                     343
# XAVIER                      52                     381
# YALE                        64                     411
# YOUNGSTOWN-STATE            59                     438
#
#                     opp_effective_field_goal_percentage  \
# ABILENE-CHRISTIAN                                 0.496
# AIR-FORCE                                         0.465
# AKRON                                             0.477
# ALABAMA-AM                                        0.488
# ALABAMA-BIRMINGHAM                                0.452
# ...                                                 ...
# WRIGHT-STATE                                      0.512
# WYOMING                                           0.447
# XAVIER                                            0.455
# YALE                                              0.489
# YOUNGSTOWN-STATE                                  0.482
#
#                     opp_field_goal_attempts  opp_field_goal_percentage  \
# ABILENE-CHRISTIAN                       844                      0.425
# AIR-FORCE                               719                      0.417
# AKRON                                   773                      0.419
# ALABAMA-AM                              877                      0.413
# ALABAMA-BIRMINGHAM                     1065                      0.393
# ...                                     ...                        ...
# WRIGHT-STATE                           1059                      0.452
# WYOMING                                 849                      0.393
# XAVIER                                  951                      0.400
# YALE                                    867                      0.422
# YOUNGSTOWN-STATE                       1067                      0.418
#
#                     opp_field_goals  opp_free_throw_attempt_rate  \
# ABILENE-CHRISTIAN               359                        0.440
# AIR-FORCE                       300                        0.349
# AKRON                           324                        0.274
# ALABAMA-AM                      362                        0.275
# ALABAMA-BIRMINGHAM              419                        0.288
# ...                             ...                          ...
# WRIGHT-STATE                    479                        0.240
# WYOMING                         334                        0.219
# XAVIER                          380                        0.212
# YALE                            366                        0.361
# YOUNGSTOWN-STATE                446                        0.288
#
#                     opp_free_throw_attempts  opp_free_throw_percentage  \
# ABILENE-CHRISTIAN                       371                      0.693
# AIR-FORCE                               251                      0.737
# AKRON                                   212                      0.670
# ALABAMA-AM                              241                      0.701
# ALABAMA-BIRMINGHAM                      307                      0.717
# ...                                     ...                        ...
# WRIGHT-STATE                            254                      0.752
# WYOMING                                 186                      0.699
# XAVIER                                  202                      0.738
# YALE                                    313                      0.687
# YOUNGSTOWN-STATE                        307                      0.733
#
#                     opp_free_throws  opp_free_throws_per_field_goal_attempt  \
# ABILENE-CHRISTIAN               257                                   0.305
# AIR-FORCE                       185                                   0.257
# AKRON                           142                                   0.184
# ALABAMA-AM                      169                                   0.193
# ALABAMA-BIRMINGHAM              220                                   0.207
# ...                             ...                                     ...
# WRIGHT-STATE                    191                                   0.180
# WYOMING                         130                                   0.153
# XAVIER                          149                                   0.157
# YALE                            215                                   0.248
# YOUNGSTOWN-STATE                225                                   0.211
#
#                    opp_offensive_rating  opp_offensive_rebound_percentage  \
# ABILENE-CHRISTIAN                  None                              26.3
# AIR-FORCE                          None                              29.4
# AKRON                              None                              23.8
# ALABAMA-AM                         None                              32.0
# ALABAMA-BIRMINGHAM                 None                              25.3
# ...                                 ...                               ...
# WRIGHT-STATE                       None                              29.3
# WYOMING                            None                              25.7
# XAVIER                             None                              23.1
# YALE                               None                              27.8
# YOUNGSTOWN-STATE                   None                              26.4
#
#                     opp_offensive_rebounds  opp_personal_fouls  opp_points  \
# ABILENE-CHRISTIAN                      138                 356        1094
# AIR-FORCE                              133                 227         853
# AKRON                                  115                 286         879
# ALABAMA-AM                             177                 233        1025
# ALABAMA-BIRMINGHAM                     172                 294        1183
# ...                                    ...                 ...         ...
# WRIGHT-STATE                           177                 324        1276
# WYOMING                                138                 269         889
# XAVIER                                 136                 302        1015
# YALE                                   153                 276        1063
# YOUNGSTOWN-STATE                       169                 329        1253
#
#                     opp_steal_percentage  opp_steals  \
# ABILENE-CHRISTIAN                    7.8          98
# AIR-FORCE                            9.4          84
# AKRON                                8.5          80
# ALABAMA-AM                          10.2         105
# ALABAMA-BIRMINGHAM                   6.9          95
# ...                                  ...         ...
# WRIGHT-STATE                        10.2         125
# WYOMING                              6.4          61
# XAVIER                               9.8         110
# YALE                                10.0         108
# YOUNGSTOWN-STATE                     8.6         108
#
#                     opp_three_point_attempt_rate  \
# ABILENE-CHRISTIAN                          0.419
# AIR-FORCE                                  0.332
# AKRON                                      0.343
# ALABAMA-AM                                 0.449
# ALABAMA-BIRMINGHAM                         0.361
# ...                                          ...
# WRIGHT-STATE                               0.355
# WYOMING                                    0.388
# XAVIER                                     0.366
# YALE                                       0.419
# YOUNGSTOWN-STATE                           0.370
#
#                     opp_three_point_field_goal_attempts  \
# ABILENE-CHRISTIAN                                   354
# AIR-FORCE                                           239
# AKRON                                               265
# ALABAMA-AM                                          394
# ALABAMA-BIRMINGHAM                                  384
# ...                                                 ...
# WRIGHT-STATE                                        376
# WYOMING                                             329
# XAVIER                                              348
# YALE                                                363
# YOUNGSTOWN-STATE                                    395
#
#                     opp_three_point_field_goal_percentage  \
# ABILENE-CHRISTIAN                                   0.336
# AIR-FORCE                                           0.285
# AKRON                                               0.336
# ALABAMA-AM                                          0.335
# ALABAMA-BIRMINGHAM                                  0.326
# ...                                                   ...
# WRIGHT-STATE                                        0.338
# WYOMING                                             0.277
# XAVIER                                              0.305
# YALE                                                0.320
# YOUNGSTOWN-STATE                                    0.344
#
#                     opp_three_point_field_goals  \
# ABILENE-CHRISTIAN                           119
# AIR-FORCE                                    68
# AKRON                                        89
# ALABAMA-AM                                  132
# ALABAMA-BIRMINGHAM                          125
# ...                                         ...
# WRIGHT-STATE                                127
# WYOMING                                      91
# XAVIER                                      106
# YALE                                        116
# YOUNGSTOWN-STATE                            136
#
#                     opp_two_point_field_goal_attempts  \
# ABILENE-CHRISTIAN                                 490
# AIR-FORCE                                         480
# AKRON                                             508
# ALABAMA-AM                                        483
# ALABAMA-BIRMINGHAM                                681
# ...                                               ...
# WRIGHT-STATE                                      683
# WYOMING                                           520
# XAVIER                                            603
# YALE                                              504
# YOUNGSTOWN-STATE                                  672
#
#                     opp_two_point_field_goal_percentage  \
# ABILENE-CHRISTIAN                                 0.490
# AIR-FORCE                                         0.483
# AKRON                                             0.463
# ALABAMA-AM                                        0.476
# ALABAMA-BIRMINGHAM                                0.432
# ...                                                 ...
# WRIGHT-STATE                                      0.515
# WYOMING                                           0.467
# XAVIER                                            0.454
# YALE                                              0.496
# YOUNGSTOWN-STATE                                  0.461
#
#                     opp_two_point_field_goals  opp_total_rebound_percentage  \
# ABILENE-CHRISTIAN                         240                          51.5
# AIR-FORCE                                 232                          54.1
# AKRON                                     235                          45.5
# ALABAMA-AM                                230                          53.3
# ALABAMA-BIRMINGHAM                        294                          47.3
# ...                                       ...                           ...
# WRIGHT-STATE                              352                          51.1
# WYOMING                                   243                          48.7
# XAVIER                                    274                          45.2
# YALE                                      250                          51.2
# YOUNGSTOWN-STATE                          310                          47.6
#
#                     opp_total_rebounds  opp_true_shooting_percentage  \
# ABILENE-CHRISTIAN                  588                         0.536
# AIR-FORCE                          459                         0.509
# AKRON                              437                         0.503
# ALABAMA-AM                         607                         0.517
# ALABAMA-BIRMINGHAM                 668                         0.489
# ...                                ...                           ...
# WRIGHT-STATE                       601                         0.541
# WYOMING                            481                         0.474
# XAVIER                             517                         0.485
# YALE                               564                         0.523
# YOUNGSTOWN-STATE                   607                         0.517
#
#                     opp_turnover_percentage  opp_turnovers  pace  \
# ABILENE-CHRISTIAN                      27.0            377  72.7
# AIR-FORCE                              17.8            182  63.6
# AKRON                                  16.8            176  66.8
# ALABAMA-AM                             17.7            213  68.7
# ALABAMA-BIRMINGHAM                     22.0            342  72.4
# ...                                     ...            ...   ...
# WRIGHT-STATE                           15.4            214  71.8
# WYOMING                                14.0            152  67.6
# XAVIER                                 17.0            215  70.2
# YALE                                   17.3            212  71.6
# YOUNGSTOWN-STATE                       14.9            212  69.0
#
#                     personal_fouls  points  simple_rating_system  \
# ABILENE-CHRISTIAN              370    1323                  2.59
# AIR-FORCE                      241     834                 -5.76
# AKRON                          233    1020                 -0.33
# ALABAMA-AM                     238     884                -14.43
# ALABAMA-BIRMINGHAM             309    1540                 12.88
# ...                            ...     ...                   ...
# WRIGHT-STATE                   246    1282                 -6.27
# WYOMING                        204    1079                 12.33
# XAVIER                         232    1209                 18.31
# YALE                           290    1103                  0.85
# YOUNGSTOWN-STATE               325    1326                 -4.89
#
#                     steal_percentage  steals  strength_of_schedule  \
# ABILENE-CHRISTIAN               15.3     193                 -0.41
# AIR-FORCE                        9.7      86                 -4.40
# AKRON                            8.9      83                 -2.33
# ALABAMA-AM                      10.7     110                 -5.03
# ALABAMA-BIRMINGHAM              14.7     202                 -1.59
# ...                              ...     ...                   ...
# WRIGHT-STATE                     7.6      93                 -4.58
# WYOMING                          6.3      60                  1.49
# XAVIER                          10.7     120                  6.19
# YALE                             8.2      89                  1.28
# YOUNGSTOWN-STATE                 7.6      95                 -5.14
#
#                     three_point_attempt_rate  three_point_field_goal_attempts  \
# ABILENE-CHRISTIAN                      0.353                              369
# AIR-FORCE                              0.471                              321
# AKRON                                  0.429                              331
# ALABAMA-AM                             0.247                              217
# ALABAMA-BIRMINGHAM                     0.319                              398
# ...                                      ...                              ...
# WRIGHT-STATE                           0.327                              326
# WYOMING                                0.453                              359
# XAVIER                                 0.397                              366
# YALE                                   0.414                              376
# YOUNGSTOWN-STATE                       0.381                              408
#
#                     three_point_field_goal_percentage  \
# ABILENE-CHRISTIAN                               0.320
# AIR-FORCE                                       0.361
# AKRON                                           0.338
# ALABAMA-AM                                      0.276
# ALABAMA-BIRMINGHAM                              0.369
# ...                                               ...
# WRIGHT-STATE                                    0.304
# WYOMING                                         0.357
# XAVIER                                          0.336
# YALE                                            0.330
# YOUNGSTOWN-STATE                                0.331
#
#                     three_point_field_goals  two_point_field_goal_attempts  \
# ABILENE-CHRISTIAN                       118                            676
# AIR-FORCE                               116                            360
# AKRON                                   112                            440
# ALABAMA-AM                               60                            662
# ALABAMA-BIRMINGHAM                      147                            850
# ...                                     ...                            ...
# WRIGHT-STATE                             99                            671
# WYOMING                                 128                            433
# XAVIER                                  123                            555
# YALE                                    124                            532
# YOUNGSTOWN-STATE                        135                            662
#
#                     two_point_field_goal_percentage  two_point_field_goals  \
# ABILENE-CHRISTIAN                             0.516                    349
# AIR-FORCE                                     0.528                    190
# AKRON                                         0.539                    237
# ALABAMA-AM                                    0.408                    270
# ALABAMA-BIRMINGHAM                            0.513                    436
# ...                                             ...                    ...
# WRIGHT-STATE                                  0.535                    359
# WYOMING                                       0.580                    251
# XAVIER                                        0.523                    290
# YALE                                          0.498                    265
# YOUNGSTOWN-STATE                              0.506                    335
#
#                     total_rebound_percentage  total_rebounds  \
# ABILENE-CHRISTIAN                       48.5             553
# AIR-FORCE                               45.9             389
# AKRON                                   54.5             523
# ALABAMA-AM                              46.7             531
# ALABAMA-BIRMINGHAM                      52.7             745
# ...                                      ...             ...
# WRIGHT-STATE                            48.9             576
# WYOMING                                 51.3             506
# XAVIER                                  54.8             627
# YALE                                    48.8             538
# YOUNGSTOWN-STATE                        52.4             668
#
#                     true_shooting_percentage  turnover_percentage  turnovers  \
# ABILENE-CHRISTIAN                      0.542                 15.0        216
# AIR-FORCE                              0.551                 21.5        207
# AKRON                                  0.553                 15.4        168
# ALABAMA-AM                             0.446                 16.6        197
# ALABAMA-BIRMINGHAM                     0.549                 12.8        206
# ...                                      ...                  ...        ...
# WRIGHT-STATE                           0.552                 15.6        214
# WYOMING                                0.584                 13.4        143
# XAVIER                                 0.554                 15.7        204
# YALE                                   0.532                 15.8        194
# YOUNGSTOWN-STATE                       0.540                 14.9        215
#
#                     win_percentage  wins
# ABILENE-CHRISTIAN            0.647    11
# AIR-FORCE                    0.571     8
# AKRON                        0.643     9
# ALABAMA-AM                   0.267     4
# ALABAMA-BIRMINGHAM           0.789    15
# ...                            ...   ...
# WRIGHT-STATE                 0.529     9
# WYOMING                      0.857    12
# XAVIER                       0.813    13
# YALE                         0.467     7
# YOUNGSTOWN-STATE             0.556    10
#
# [358 rows x 84 columns]

# %%
missing = ['Loyola (IL)',
 'Louisiana-Monroe',
 'UNC',
 'Miami (FL)',
 'UConn',
 'College of Charleston',
 'Alabama-Birmingham',
 'Albany (NY)',
 'St. Francis (NY)',
 'Prairie View',
 'Savannah St.',
 'Omaha',
 'Maryland-Eastern Shore',
 'Texas-Arlington',
 'Loyola (MD)',
 'NC St.',
 'Pitt',
 'Citadel',
 'Grambling',
 "St. John's (NY)",
 'UC-Irvine',
 'UIC',
 'California Baptist',
 'Bowling Green St.',
 'Bethune-Cookman',
 'Gardner-Webb',
 'Florida International',
 'Texas-Rio Grande Valley',
 'Saint Francis (PA)',
 'UC-Riverside',
 'Purdue-Fort Wayne',
 'UMass',
 'UC-Davis',
 'Miami (OH)',
 'Texas A&M-Corpus Christi',
 'Arkansas-Pine Bluff',
 'UC-San Diego']
in_kp = ['Loyola Chicago','Louisiana Monroe','North Carolina','Miami FL','Connecticut','Charleston','UAB','Albany','St. Francis NY',
        'Prairie View A&M','Savannah St.','Nebraska Omaha','Maryland Eastern Shore','UT Arlington','Loyola MD','N.C. State','Pittsburgh','The Citadel',
        'Grambling St.',"St. John's",'UC Irvine','Cal Baptist','Bowling Green','Bethune Cookman','Gardner Webb','FIU','UT Rio Grande Valley','St. Francis PA',
        'UC Riverside','Purdue Fort Wayne','Massachusetts','UC Davis','Miami OH','Texas A&M Corpus Christi','Arkansas Pine Bluff','UC San Diego']


from kenpompy.utils import login
import kenpompy.summary as kp
import kenpompy.misc as kpm
kp_df2 = pd.DataFrame()
b = ['Rk', 'Team', 'Conf', 'W-L', 'AdjEM', 'AdjO', 'AdjO_r', 'AdjD', 'AdjD_R','AdjT', 'AdjT_r', 'Luck', 'Luck_r', 'AdjEM', 'AdjEM_r', 'OppO', 'OppO_r','OppD', 'OppD_r', 'AdjEM', 'AdjEM_r', 'Seed']
browser = login("xxxx", 'xxxx')
temp_df = kpm.get_pomeroy_ratings(browser,season = 2022)
temp_df.columns = b
temp_df = temp_df.drop([temp_df.columns[i] for i in [0,2,3,6,8,10,12,14,16,18,20,19,21]],1)
temp_df['Team'] = temp_df.Team.replace(dict(zip(in_kp,missing)))
temp_df['Season'] = 2022
kp_df2 = pd.concat([kp_df2,temp_df])
#time.sleep(10)
kp_df2[kp_df2.Team != "Team"].dropna(axis = 0)
kp_df2.Team = kp_df2.Team.str.replace(" St.",' State')
# Out:
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# The default value of regex will change from True to False in a future version.

# %%
team_1 = 'Purdue'
team_2 = 'Nebraska'
home_team = team_1
away_team = team_2
if team_1 in df_agg.name.unique().tolist():
    if team_2 in df_agg.name.unique().tolist():
        temp_df_2 = df_agg.loc[df_agg.name == team_1].loc[:,df_agg.columns[df_agg.columns.str.contains('percen') | df_agg.columns.str.contains('rat') | (df_agg.columns == 'pace') | (df_agg.columns == 'name')]]
        temp_df_3 = df_agg.loc[df_agg.name == team_2].loc[:,df_agg.columns[df_agg.columns.str.contains('percen') | df_agg.columns.str.contains('rat') | (df_agg.columns == 'pace') | (df_agg.columns == 'name')]]
        old_names = temp_df_2.columns[temp_df_2.columns.str.contains('opp_')].to_list()
        new_names = [i.replace('opp','allowed') for i in temp_df_2.columns[temp_df_2.columns.str.contains('opp_')].to_list()]
        name_dict = dict(zip(old_names,new_names))
        temp_df_2_dict = temp_df_2.rename(columns = name_dict).to_dict(orient = 'list')
        temp_df_2_dict.update(temp_df_3.iloc[0,:10].rename(dict(zip(temp_df_3.iloc[0,:10].index,['opp_'+str(i) for i in temp_df_3.iloc[0,:10].index]))).to_frame().transpose().to_dict(orient = 'list'))
        temp_df_2_dict.update(temp_df_3.iloc[0,25:].rename(dict(zip(temp_df_3.iloc[0,25:].index,['opp_'+str(i) for i in temp_df_3.iloc[0,25:].index]))).to_frame().transpose().to_dict(orient = 'list'))
        temp_df_2_dict.update(temp_df_3.iloc[0,10:25].rename(dict(zip(temp_df_3.iloc[0,10:25].index,[i + "_allowed" for i in temp_df_3.iloc[0,10:25].index]))).to_frame().transpose().to_dict(orient = 'list'))
        temp_df_3_dict = temp_df_3.rename(columns = name_dict).to_dict(orient = 'list')
        temp_df_3_dict.update(temp_df_2.iloc[0,:10].rename(dict(zip(temp_df_2.iloc[0,:10].index,['opp_'+str(i) for i in temp_df_2.iloc[0,:10].index]))).to_frame().transpose().to_dict(orient = 'list'))
        temp_df_3_dict.update(temp_df_2.iloc[0,25:].rename(dict(zip(temp_df_2.iloc[0,25:].index,['opp_'+str(i) for i in temp_df_2.iloc[0,25:].index]))).to_frame().transpose().to_dict(orient = 'list'))
        temp_df_3_dict.update(temp_df_2.iloc[0,10:25].rename(dict(zip(temp_df_2.iloc[0,10:25].index,[i + "_allowed" for i in temp_df_2.iloc[0,10:25].index]))).to_frame().transpose().to_dict(orient = 'list'))
        for i in temp_df_3_dict.keys():
            temp_df_2_dict[i]+=(temp_df_3_dict[i])
        master_dict = {key:[] for key in temp_df_2_dict.keys()}

        for i in temp_df_2_dict.keys():
            master_dict[i] += temp_df_2_dict[i]
        df_pred = pd.DataFrame.from_dict(master_dict)
        df_pred = df_pred[df_pred.name == home_team]
        df_pred['home'] = 1
        for i in df_pred.loc[:,df_pred.columns[df_pred.columns.str.contains('percent')]].columns:
             if df_pred[i].max() > 1:
                df_pred[i] = [j/100 for j in df_pred[i]]
df_pred = pd.merge(df_pred,kp_df2,left_on = 'name',right_on = "Team",how = 'left').drop("Team",axis = 1)
df_wl = df_pred[wl_cols]

loss_prob = clf.predict_proba(df_wl)[0][0]
win_prob = clf.predict_proba(df_wl)[0][1]

if win_prob >= loss_prob:
    print(home_team + ' has a ' + str(round(win_prob*100,2)) + '% chance of winning at home against ' +away_team)
else:
    print(away_team + ' has a ' + str(round(loss_prob*100,2)) + '% chance of winning on the road against ' + home_team)
# Out:
# Purdue has a 98.14% chance of winning at home against Nebraska

# %%
df2
# Out:
#        effective_field_goal_percentage  offensive_rating  \
# 0                                0.513             108.9
# 1                                0.528             107.6
# 2                                0.474             103.9
# 3                                0.503             108.2
# 4                                0.469             102.6
# ...                                ...               ...
# 56167                            0.500             103.1
# 56168                            0.510             102.5
# 56169                            0.527             103.6
# 56170                            0.520             107.4
# 56171                            0.516             108.9
#
#        allowed_effective_field_goal_percentage  \
# 0                                        0.486
# 1                                        0.448
# 2                                        0.439
# 3                                        0.530
# 4                                        0.498
# ...                                        ...
# 56167                                    0.464
# 56168                                    0.517
# 56169                                    0.483
# 56170                                    0.498
# 56171                                    0.529
#
#        allowed_three_point_field_goal_percentage  \
# 0                                          0.343
# 1                                          0.321
# 2                                          0.285
# 3                                          0.388
# 4                                          0.365
# ...                                          ...
# 56167                                      0.323
# 56168                                      0.362
# 56169                                      0.312
# 56170                                      0.300
# 56171                                      0.361
#
#        allowed_total_rebound_percentage  simple_rating_system  \
# 0                                 0.495                 11.75
# 1                                 0.465                 13.73
# 2                                 0.486                 11.08
# 3                                 0.479                  1.74
# 4                                 0.462                 -1.66
# ...                                 ...                   ...
# 56167                             0.454                  9.41
# 56168                             0.511                  1.44
# 56169                             0.503                 -5.91
# 56170                             0.516                  4.20
# 56171                             0.479                 -0.98
#
#        three_point_field_goal_percentage  two_point_field_goal_percentage  \
# 0                                  0.352                            0.505
# 1                                  0.379                            0.516
# 2                                  0.310                            0.479
# 3                                  0.360                            0.486
# 4                                  0.329                            0.458
# ...                                  ...                              ...
# 56167                              0.340                            0.496
# 56168                              0.340                            0.510
# 56169                              0.342                            0.538
# 56170                              0.338                            0.527
# 56171                              0.346                            0.515
#
#        total_rebound_percentage  turnover_percentage  win_percentage  \
# 0                         0.505                0.154           0.658
# 1                         0.535                0.174           0.730
# 2                         0.514                0.154           0.639
# 3                         0.521                0.156           0.529
# 4                         0.538                0.167           0.576
# ...                         ...                  ...             ...
# 56167                     0.546                0.156           0.742
# 56168                     0.489                0.159           0.543
# 56169                     0.497                0.160           0.613
# 56170                     0.484                0.155           0.667
# 56171                     0.521                0.156           0.636
#
#        opp_block_percentage  opp_effective_field_goal_percentage  \
# 0                     0.139                                0.517
# 1                     0.162                                0.474
# 2                     0.137                                0.528
# 3                     0.103                                0.541
# 4                     0.126                                0.510
# ...                     ...                                  ...
# 56167                 0.089                                0.510
# 56168                 0.126                                0.500
# 56169                 0.117                                0.471
# 56170                 0.082                                0.516
# 56171                 0.103                                0.520
#
#        opp_offensive_rating  opp_simple_rating_system  \
# 0                     106.6                     12.63
# 1                     103.9                     11.08
# 2                     107.6                     13.73
# 3                     113.0                      0.98
# 4                     113.9                     -5.53
# ...                     ...                       ...
# 56167                 102.5                      1.44
# 56168                 103.1                      9.41
# 56169                  98.0                    -11.30
# 56170                 108.9                     -0.98
# 56171                 107.4                      4.20
#
#        opp_three_point_field_goal_percentage  \
# 0                                      0.380
# 1                                      0.310
# 2                                      0.379
# 3                                      0.376
# 4                                      0.325
# ...                                      ...
# 56167                                  0.340
# 56168                                  0.340
# 56169                                  0.297
# 56170                                  0.346
# 56171                                  0.338
#
#        opp_two_point_field_goal_percentage  opp_total_rebound_percentage  \
# 0                                    0.497                         0.508
# 1                                    0.479                         0.514
# 2                                    0.516                         0.535
# 3                                    0.529                         0.515
# 4                                    0.524                         0.495
# ...                                    ...                           ...
# 56167                                0.510                         0.489
# 56168                                0.496                         0.546
# 56169                                0.485                         0.492
# 56170                                0.515                         0.521
# 56171                                0.527                         0.484
#
#        opp_turnover_percentage  opp_win_percentage  \
# 0                        0.183               0.611
# 1                        0.154               0.639
# 2                        0.174               0.730
# 3                        0.153               0.676
# 4                        0.116               0.629
# ...                        ...                 ...
# 56167                    0.159               0.543
# 56168                    0.156               0.742
# 56169                    0.156               0.419
# 56170                    0.156               0.636
# 56171                    0.155               0.667
#
#        opp_effective_field_goal_percentage_allowed  \
# 0                                            0.454
# 1                                            0.439
# 2                                            0.448
# 3                                            0.491
# 4                                            0.485
# ...                                            ...
# 56167                                        0.517
# 56168                                        0.464
# 56169                                        0.493
# 56170                                        0.529
# 56171                                        0.498
#
#        opp_steal_percentage_allowed  \
# 0                             0.100
# 1                             0.089
# 2                             0.118
# 3                             0.088
# 4                             0.073
# ...                             ...
# 56167                         0.090
# 56168                         0.097
# 56169                         0.079
# 56170                         0.087
# 56171                         0.078
#
#        opp_three_point_field_goal_percentage_allowed  \
# 0                                              0.329
# 1                                              0.285
# 2                                              0.321
# 3                                              0.322
# 4                                              0.337
# ...                                              ...
# 56167                                          0.362
# 56168                                          0.323
# 56169                                          0.351
# 56170                                          0.361
# 56171                                          0.300
#
#        opp_total_rebound_percentage_allowed  home   AdjO   AdjD   Luck   OppO  \
# 0                                     0.492     0  113.8   99.9  0.044  108.9
# 1                                     0.486     0  111.3   93.7 -0.043  106.3
# 2                                     0.465     1  107.1   93.7  0.008  108.5
# 3                                     0.485     0  109.5  107.5  0.057  107.8
# 4                                     0.505     0  102.8  101.5  0.080  105.6
# ...                                     ...   ...    ...    ...    ...    ...
# 56167                                 0.511     1  105.8   94.4  0.026  103.1
# 56168                                 0.454     0  104.5  102.5  0.020  103.0
# 56169                                 0.508     0  100.6  105.5  0.101  101.0
# 56170                                 0.479     1  108.9  103.3  0.023  102.3
# 56171                                 0.516     0  106.9  107.0  0.032  100.1
#
#         OppD
# 0      100.7
# 1      102.2
# 2      102.6
# 3      104.3
# 4      104.7
# ...      ...
# 56167  101.2
# 56168  101.6
# 56169  106.1
# 56170  101.4
# 56171  105.4
#
# [56172 rows x 30 columns]

# %% [markdown]
# # Predicting Spreads

# %%
df_points = pd.read_csv('ml_df_l4.csv')
df_points = df_points.drop([df_points.columns[i] for i in [6,39,66,67,68,69,70,72]],axis = 1)

idx_to_remove = []
for i in df_points.columns.tolist():
    stat,p = stats.normaltest(df_points[i])
    if p <= 0.05:
        zscores = stats.zscore(df_points[i])
        zscores = np.abs(zscores)
        idx_list = []
        for idx,i in enumerate(zscores):
            if i >=3.2:
                idx_list.append(idx)
        for i in idx_list:
            if i not in idx_to_remove:
                idx_to_remove.append(i)
print("Identified {} outliers to remove".format(len(idx_to_remove)))

df_points['spread'] = df_points.apply(lambda x:x.points_for-x.points_against,axis = 1)
df_points = df_points.drop(['points_for','points_against'],axis = 1)
df_points = df_points.drop(idx_to_remove,axis = 0)

corr=df_points.corr()
high_corr_var=np.where(corr>0.9)
high_corr_var=[(corr.columns[x],corr.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]
for tup in high_corr_var:
    if tup[1] != 'points_for':
        print('Removing {} as it is highly correllated with {}'.format(tup[1],tup[0]))

to_drop = []
for x,y in high_corr_var:
    if y not in to_drop:
        to_drop.append(y)

df_points = df_points.drop([i for i in to_drop],axis = 1)

corr=df_points.corr()
high_corr_var=np.where(corr>0.9)
high_corr_var=[(corr.columns[x],corr.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]
assert high_corr_var == []
X = df_points.drop('spread',1)
y = df_points.spread
X_train,X_test,y_train,y_test = train_test_split(X,y)
spread_cols = X_train.columns.tolist()
X_train
# Out:
# Identified 5618 outliers to remove
# Removing field_goal_percentage as it is highly correllated with effective_field_goal_percentage
# Removing true_shooting_percentage as it is highly correllated with effective_field_goal_percentage
# Removing allowed_field_goal_percentage as it is highly correllated with allowed_effective_field_goal_percentage
# Removing allowed_true_shooting_percentage as it is highly correllated with allowed_effective_field_goal_percentage
# Removing allowed_true_shooting_percentage as it is highly correllated with allowed_field_goal_percentage
# Removing AdjT as it is highly correllated with pace
# Removing opp_field_goal_percentage as it is highly correllated with opp_effective_field_goal_percentage
# Removing opp_true_shooting_percentage as it is highly correllated with opp_effective_field_goal_percentage
# Removing opp_true_shooting_percentage as it is highly correllated with opp_field_goal_percentage
# Removing opp_field_goal_percentage_allowed as it is highly correllated with opp_effective_field_goal_percentage_allowed
# Removing opp_true_shooting_percentage_allowed as it is highly correllated with opp_effective_field_goal_percentage_allowed
# Removing opp_true_shooting_percentage_allowed as it is highly correllated with opp_field_goal_percentage_allowed
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#        assist_percentage  block_percentage  effective_field_goal_percentage  \
# 47607               58.9               6.9                            0.489
# 47418               44.4               8.9                            0.500
# 53514               51.1               9.7                            0.503
# 37318               56.8              12.9                            0.529
# 43765               47.8              10.5                            0.510
# ...                  ...               ...                              ...
# 13682               42.1               8.1                            0.452
# 42284               59.7              15.2                            0.554
# 3007                40.3               8.5                            0.504
# 32882               54.9               9.0                            0.488
# 31038               48.9               9.0                            0.524
#
#        free_throw_attempt_rate  free_throw_percentage  offensive_rating  \
# 47607                    0.377                  0.737             100.1
# 47418                    0.271                  0.712             102.3
# 53514                    0.269                  0.764             103.8
# 37318                    0.398                  0.695             109.0
# 43765                    0.343                  0.718             106.3
# ...                        ...                    ...               ...
# 13682                    0.429                  0.717              96.7
# 42284                    0.333                  0.754             116.2
# 3007                     0.439                  0.711             111.7
# 32882                    0.327                  0.707              99.6
# 31038                    0.369                  0.685             108.6
#
#        offensive_rebound_percentage  allowed_assist_percentage  \
# 47607                          26.9                       48.1
# 47418                          27.2                       53.6
# 53514                          24.1                       47.7
# 37318                          27.2                       43.8
# 43765                          33.4                       51.9
# ...                             ...                        ...
# 13682                          35.6                       53.2
# 42284                          30.9                       51.2
# 3007                           29.1                       44.2
# 32882                          26.0                       60.9
# 31038                          29.4                       52.0
#
#        allowed_block_percentage  allowed_effective_field_goal_percentage  \
# 47607                      10.4                                    0.506
# 47418                       7.5                                    0.520
# 53514                       9.6                                    0.464
# 37318                       8.7                                    0.431
# 43765                       8.3                                    0.476
# ...                         ...                                      ...
# 13682                      10.0                                    0.482
# 42284                       6.3                                    0.475
# 3007                        9.6                                    0.494
# 32882                      10.7                                    0.481
# 31038                       7.0                                    0.458
#
#        allowed_free_throw_attempt_rate  allowed_free_throw_percentage  \
# 47607                            0.311                          0.712
# 47418                            0.288                          0.736
# 53514                            0.253                          0.690
# 37318                            0.344                          0.677
# 43765                            0.287                          0.739
# ...                                ...                            ...
# 13682                            0.455                          0.703
# 42284                            0.343                          0.653
# 3007                             0.380                          0.694
# 32882                            0.311                          0.698
# 31038                            0.365                          0.705
#
#        allowed_offensive_rebound_percentage  allowed_steal_percentage  \
# 47607                                  28.8                      10.7
# 47418                                  26.9                       7.8
# 53514                                  25.9                       7.7
# 37318                                  29.2                       8.0
# 43765                                  28.1                       9.2
# ...                                     ...                       ...
# 13682                                  32.9                      10.4
# 42284                                  29.4                       8.8
# 3007                                   32.8                       6.9
# 32882                                  32.6                       8.8
# 31038                                  26.7                       8.2
#
#        allowed_three_point_attempt_rate  \
# 47607                             0.282
# 47418                             0.398
# 53514                             0.325
# 37318                             0.306
# 43765                             0.347
# ...                                 ...
# 13682                             0.339
# 42284                             0.406
# 3007                              0.317
# 32882                             0.332
# 31038                             0.424
#
#        allowed_three_point_field_goal_percentage  \
# 47607                                      0.392
# 47418                                      0.356
# 53514                                      0.331
# 37318                                      0.294
# 43765                                      0.330
# ...                                          ...
# 13682                                      0.336
# 42284                                      0.348
# 3007                                       0.327
# 32882                                      0.340
# 31038                                      0.291
#
#        allowed_two_point_field_goal_percentage  \
# 47607                                    0.474
# 47418                                    0.511
# 53514                                    0.449
# 37318                                    0.426
# 43765                                    0.466
# ...                                        ...
# 13682                                    0.470
# 42284                                    0.442
# 3007                                     0.496
# 32882                                    0.467
# 31038                                    0.474
#
#        allowed_total_rebound_percentage  allowed_turnover_percentage  pace  \
# 47607                              50.6                         14.2  65.4
# 47418                              49.9                         14.3  70.7
# 53514                              50.4                         14.8  64.4
# 37318                              49.2                         12.0  69.2
# 43765                              47.0                         16.0  64.7
# ...                                 ...                          ...   ...
# 13682                              48.9                         17.4  61.3
# 42284                              47.7                         15.6  69.4
# 3007                               51.9                         14.3  70.9
# 32882                              52.4                         14.3  65.5
# 31038                              47.7                         13.5  67.9
#
#        simple_rating_system  steal_percentage  three_point_attempt_rate  \
# 47607                 -4.85               8.0                     0.399
# 47418                 -5.09               7.2                     0.300
# 53514                 15.95               6.9                     0.445
# 37318                 17.20               6.0                     0.380
# 43765                 14.48               9.9                     0.326
# ...                     ...               ...                       ...
# 13682                -15.52               8.9                     0.346
# 42284                 21.55               8.5                     0.320
# 3007                   2.73               8.4                     0.345
# 32882                 -6.52               7.5                     0.316
# 31038                  6.17               6.3                     0.419
#
#        three_point_field_goal_percentage  two_point_field_goal_percentage  \
# 47607                              0.338                            0.477
# 47418                              0.338                            0.497
# 53514                              0.352                            0.483
# 37318                              0.382                            0.501
# 43765                              0.356                            0.498
# ...                                  ...                              ...
# 13682                              0.301                            0.453
# 42284                              0.367                            0.556
# 3007                               0.347                            0.495
# 32882                              0.359                            0.465
# 31038                              0.359                            0.514
#
#        total_rebound_percentage  turnover_percentage  win_percentage  \
# 47607                      49.4                 17.2           0.467
# 47418                      50.1                 14.9           0.500
# 53514                      49.6                 13.8           0.677
# 37318                      50.8                 14.7           0.576
# 43765                      53.0                 16.6           0.636
# ...                         ...                  ...             ...
# 13682                      51.1                 19.2           0.344
# 42284                      52.3                 13.7           0.838
# 3007                       48.1                 11.6           0.714
# 32882                      47.6                 15.9           0.438
# 31038                      52.3                 14.9           0.656
#
#        opp_assist_percentage  opp_block_percentage  \
# 47607                   49.5                   7.0
# 47418                   59.1                   5.8
# 53514                   55.4                   8.1
# 37318                   58.7                  13.8
# 43765                   49.3                  13.7
# ...                      ...                   ...
# 13682                   56.7                  12.5
# 42284                   51.2                  13.4
# 3007                    49.9                  12.2
# 32882                   51.2                   6.1
# 31038                   56.7                  10.0
#
#        opp_effective_field_goal_percentage  opp_free_throw_attempt_rate  \
# 47607                                0.471                        0.484
# 47418                                0.541                        0.390
# 53514                                0.526                        0.375
# 37318                                0.497                        0.376
# 43765                                0.537                        0.384
# ...                                    ...                          ...
# 13682                                0.553                        0.379
# 42284                                0.530                        0.419
# 3007                                 0.503                        0.423
# 32882                                0.540                        0.339
# 31038                                0.443                        0.368
#
#        opp_free_throw_percentage  opp_offensive_rating  \
# 47607                      0.666                  99.0
# 47418                      0.679                 106.8
# 53514                      0.720                 105.1
# 37318                      0.694                 107.5
# 43765                      0.689                 113.1
# ...                          ...                   ...
# 13682                      0.685                 109.9
# 42284                      0.739                 111.9
# 3007                       0.689                 106.1
# 32882                      0.744                 107.9
# 31038                      0.685                  95.9
#
#        opp_offensive_rebound_percentage  opp_pace  opp_simple_rating_system  \
# 47607                              28.0      67.9                      3.27
# 47418                              26.5      69.7                      6.70
# 53514                              27.6      73.0                      3.47
# 37318                              30.9      71.3                     10.23
# 43765                              33.6      72.6                     18.87
# ...                                 ...       ...                       ...
# 13682                              32.4      62.6                      0.66
# 42284                              36.4      67.3                     21.43
# 3007                               29.6      65.1                     17.84
# 32882                              26.8      65.6                     -7.64
# 31038                              28.3      65.6                     -5.42
#
#        opp_steal_percentage  opp_three_point_attempt_rate  \
# 47607                   9.9                         0.387
# 47418                   9.2                         0.393
# 53514                  11.1                         0.368
# 37318                  10.0                         0.273
# 43765                  10.2                         0.313
# ...                     ...                           ...
# 13682                  10.6                         0.356
# 42284                   8.8                         0.296
# 3007                   11.8                         0.329
# 32882                   7.9                         0.349
# 31038                   6.9                         0.300
#
#        opp_three_point_field_goal_percentage  \
# 47607                                  0.347
# 47418                                  0.366
# 53514                                  0.327
# 37318                                  0.397
# 43765                                  0.347
# ...                                      ...
# 13682                                  0.369
# 42284                                  0.354
# 3007                                   0.324
# 32882                                  0.398
# 31038                                  0.329
#
#        opp_two_point_field_goal_percentage  opp_total_rebound_percentage  \
# 47607                                0.441                          46.0
# 47418                                0.536                          52.0
# 53514                                0.548                          49.5
# 37318                                0.461                          50.0
# 43765                                0.544                          52.7
# ...                                    ...                           ...
# 13682                                0.553                          53.1
# 42284                                0.529                          56.9
# 3007                                 0.511                          50.2
# 32882                                0.509                          47.3
# 31038                                0.421                          48.0
#
#        opp_turnover_percentage  opp_win_percentage  \
# 47607                     16.4               0.429
# 47418                     16.4               0.625
# 53514                     17.4               0.576
# 37318                     13.2               0.500
# 43765                     14.1               0.743
# ...                        ...                 ...
# 13682                     17.4               0.758
# 42284                     15.9               0.811
# 3007                      14.9               0.714
# 32882                     16.3               0.355
# 31038                     14.6               0.194
#
#        opp_assist_percentage_allowed  opp_block_percentage_allowed  \
# 47607                           50.8                          13.3
# 47418                           50.9                           7.4
# 53514                           58.5                           7.0
# 37318                           55.7                           9.7
# 43765                           49.5                           7.1
# ...                              ...                           ...
# 13682                           46.1                           8.6
# 42284                           47.9                           7.8
# 3007                            43.8                           8.3
# 32882                           52.0                           8.6
# 31038                           51.8                           9.1
#
#        opp_effective_field_goal_percentage_allowed  \
# 47607                                        0.523
# 47418                                        0.516
# 53514                                        0.524
# 37318                                        0.498
# 43765                                        0.479
# ...                                            ...
# 13682                                        0.410
# 42284                                        0.466
# 3007                                         0.452
# 32882                                        0.540
# 31038                                        0.520
#
#        opp_free_throw_attempt_rate_allowed  opp_free_throw_percentage_allowed  \
# 47607                                0.412                              0.698
# 47418                                0.239                              0.725
# 53514                                0.245                              0.691
# 37318                                0.428                              0.700
# 43765                                0.373                              0.715
# ...                                    ...                                ...
# 13682                                0.422                              0.675
# 42284                                0.268                              0.705
# 3007                                 0.298                              0.711
# 32882                                0.367                              0.727
# 31038                                0.474                              0.685
#
#        opp_offensive_rebound_percentage_allowed  opp_steal_percentage_allowed  \
# 47607                                      33.8                           9.8
# 47418                                      23.8                           8.9
# 53514                                      30.1                           9.6
# 37318                                      30.0                           7.1
# 43765                                      29.5                           6.9
# ...                                         ...                           ...
# 13682                                      29.7                           8.3
# 42284                                      25.2                           8.6
# 3007                                       29.6                           6.3
# 32882                                      33.6                           9.4
# 31038                                      29.0                           7.8
#
#        opp_three_point_attempt_rate_allowed  \
# 47607                                 0.326
# 47418                                 0.426
# 53514                                 0.426
# 37318                                 0.349
# 43765                                 0.361
# ...                                     ...
# 13682                                 0.350
# 42284                                 0.386
# 3007                                  0.316
# 32882                                 0.373
# 31038                                 0.325
#
#        opp_three_point_field_goal_percentage_allowed  \
# 47607                                          0.332
# 47418                                          0.342
# 53514                                          0.346
# 37318                                          0.359
# 43765                                          0.349
# ...                                              ...
# 13682                                          0.282
# 42284                                          0.343
# 3007                                           0.293
# 32882                                          0.373
# 31038                                          0.363
#
#        opp_two_point_field_goal_percentage_allowed  \
# 47607                                        0.535
# 47418                                        0.517
# 53514                                        0.526
# 37318                                        0.477
# 43765                                        0.454
# ...                                            ...
# 13682                                        0.402
# 42284                                        0.436
# 3007                                         0.459
# 32882                                        0.529
# 31038                                        0.507
#
#        opp_total_rebound_percentage_allowed  opp_turnover_percentage_allowed  \
# 47607                                  54.0                             18.5
# 47418                                  48.0                             15.9
# 53514                                  50.5                             17.6
# 37318                                  50.0                             17.0
# 43765                                  47.3                             16.9
# ...                                     ...                              ...
# 13682                                  46.9                             18.2
# 42284                                  43.1                             15.7
# 3007                                   49.8                             19.0
# 32882                                  52.7                             15.6
# 31038                                  52.0                             15.7
#
#        home   AdjO   AdjD   Luck   OppO   OppD
# 47607     0  103.1  106.9  0.043  105.6  104.7
# 47418     0  103.2  107.7  0.077  104.0  104.3
# 53514     0  110.8   91.9  0.031  108.7   96.9
# 37318     0  113.6   94.9 -0.106  109.2  100.6
# 43765     0  109.9   94.9  0.031  110.7  101.3
# ...     ...    ...    ...    ...    ...    ...
# 13682     1  107.6  111.4  0.085  103.9  105.8
# 42284     1  122.7   96.5  0.034  109.7   99.0
# 3007      0  112.0  106.2  0.064  105.2  105.9
# 32882     1   98.0  104.1  0.031  104.3  107.6
# 31038     1  108.1   99.6 -0.043  105.5  105.6
#
# [37915 rows x 62 columns]

# %%
import statsmodels.api as sm
X2 = sm.add_constant(X_train)
est = sm.OLS(y_train, X2)
est2 = est.fit()
print(est2.summary())
# Out:
# In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 spread   R-squared:                       0.512
# Model:                            OLS   Adj. R-squared:                  0.511
# Method:                 Least Squares   F-statistic:                     639.4
# Date:                Sun, 16 Jan 2022   Prob (F-statistic):               0.00
# Time:                        14:05:45   Log-Likelihood:            -1.4185e+05
# No. Observations:               37915   AIC:                         2.838e+05
# Df Residuals:                   37852   BIC:                         2.844e+05
# Df Model:                          62
# Covariance Type:            nonrobust
# =================================================================================================================
#                                                     coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------
# const                                         -1302.2728   2742.642     -0.475      0.635   -6677.925    4073.379
# assist_percentage                                 0.0103      0.012      0.839      0.401      -0.014       0.035
# block_percentage                                 -0.0147      0.030     -0.491      0.623      -0.073       0.044
# effective_field_goal_percentage                  16.5401     31.727      0.521      0.602     -45.645      78.726
# free_throw_attempt_rate                           1.3130      2.542      0.517      0.605      -3.669       6.295
# free_throw_percentage                             3.0768      4.327      0.711      0.477      -5.404      11.557
# offensive_rating                                  0.0161      0.154      0.105      0.917      -0.286       0.318
# offensive_rebound_percentage                      0.1100      0.184      0.598      0.550      -0.250       0.470
# allowed_assist_percentage                        -0.0109      0.015     -0.712      0.476      -0.041       0.019
# allowed_block_percentage                         -0.0105      0.040     -0.262      0.793      -0.089       0.068
# allowed_effective_field_goal_percentage         -37.1190     33.661     -1.103      0.270    -103.096      28.858
# allowed_free_throw_attempt_rate                   0.2501      1.447      0.173      0.863      -2.587       3.087
# allowed_free_throw_percentage                     0.5697      2.760      0.206      0.836      -4.839       5.979
# allowed_offensive_rebound_percentage             -0.0939      0.158     -0.593      0.553      -0.404       0.216
# allowed_steal_percentage                         -0.0083      0.079     -0.105      0.917      -0.163       0.146
# allowed_three_point_attempt_rate                  1.9263      2.109      0.913      0.361      -2.207       6.060
# allowed_three_point_field_goal_percentage        19.3250     17.947      1.077      0.282     -15.851      54.501
# allowed_two_point_field_goal_percentage          20.6323     21.243      0.971      0.331     -21.005      62.270
# allowed_total_rebound_percentage                 -2.0920     15.735     -0.133      0.894     -32.933      28.748
# allowed_turnover_percentage                      -0.0752      0.087     -0.865      0.387      -0.245       0.095
# pace                                             -0.0032      0.020     -0.164      0.870      -0.042       0.036
# simple_rating_system                              0.8598      0.019     44.260      0.000       0.822       0.898
# steal_percentage                                  0.0505      0.070      0.724      0.469      -0.086       0.187
# three_point_attempt_rate                         -1.3947      1.822     -0.766      0.444      -4.966       2.176
# three_point_field_goal_percentage                -3.6107     13.191     -0.274      0.784     -29.466      22.245
# two_point_field_goal_percentage                  -4.7199     15.551     -0.304      0.761     -35.200      25.760
# total_rebound_percentage                         -2.2999     15.746     -0.146      0.884     -33.163      28.563
# turnover_percentage                              -0.0608      0.222     -0.274      0.784      -0.496       0.374
# win_percentage                                    1.3048      1.673      0.780      0.435      -1.974       4.584
# opp_assist_percentage                             0.0216      0.012      1.775      0.076      -0.002       0.045
# opp_block_percentage                              0.0074      0.030      0.250      0.803      -0.051       0.065
# opp_effective_field_goal_percentage               0.8902     31.748      0.028      0.978     -61.338      63.118
# opp_free_throw_attempt_rate                       2.5826      2.547      1.014      0.311      -2.409       7.574
# opp_free_throw_percentage                         4.1589      4.309      0.965      0.334      -4.287      12.604
# opp_offensive_rating                             -0.2424      0.151     -1.602      0.109      -0.539       0.054
# opp_offensive_rebound_percentage                  0.0561      0.181      0.311      0.756      -0.298       0.410
# opp_pace                                          0.0033      0.020      0.162      0.871      -0.036       0.042
# opp_simple_rating_system                         -0.8725      0.012    -73.147      0.000      -0.896      -0.849
# opp_steal_percentage                              0.0106      0.067      0.157      0.876      -0.122       0.143
# opp_three_point_attempt_rate                      2.0952      1.803      1.162      0.245      -1.438       5.629
# opp_three_point_field_goal_percentage            12.1999     12.913      0.945      0.345     -13.110      37.510
# opp_two_point_field_goal_percentage              13.2605     15.343      0.864      0.387     -16.812      43.333
# opp_total_rebound_percentage                     15.3429     22.387      0.685      0.493     -28.536      59.221
# opp_turnover_percentage                          -0.2690      0.222     -1.212      0.225      -0.704       0.166
# opp_win_percentage                               -1.2274      0.901     -1.362      0.173      -2.994       0.539
# opp_assist_percentage_allowed                    -0.0074      0.015     -0.481      0.631      -0.038       0.023
# opp_block_percentage_allowed                     -0.0047      0.040     -0.117      0.907      -0.083       0.074
# opp_effective_field_goal_percentage_allowed      13.1651     32.507      0.405      0.685     -50.549      76.879
# opp_free_throw_attempt_rate_allowed               0.1747      1.360      0.128      0.898      -2.491       2.840
# opp_free_throw_percentage_allowed                -2.5964      2.718     -0.955      0.339      -7.923       2.730
# opp_offensive_rebound_percentage_allowed          0.0690      0.153      0.452      0.652      -0.230       0.368
# opp_steal_percentage_allowed                     -0.0905      0.078     -1.166      0.244      -0.243       0.062
# opp_three_point_attempt_rate_allowed              1.9460      2.102      0.926      0.355      -2.174       6.066
# opp_three_point_field_goal_percentage_allowed    -3.1381     17.435     -0.180      0.857     -37.310      31.034
# opp_two_point_field_goal_percentage_allowed      -4.3580     20.650     -0.211      0.833     -44.832      36.116
# opp_total_rebound_percentage_allowed             15.2404     22.380      0.681      0.496     -28.625      59.106
# opp_turnover_percentage_allowed                  -0.0808      0.077     -1.047      0.295      -0.232       0.070
# home                                              5.1413      0.110     46.800      0.000       4.926       5.357
# AdjO                                             -0.0143      0.025     -0.563      0.573      -0.064       0.035
# AdjD                                             -0.0523      0.028     -1.848      0.065      -0.108       0.003
# Luck                                             -2.2133      1.806     -1.226      0.220      -5.753       1.326
# OppO                                             -0.0201      0.039     -0.518      0.604      -0.096       0.056
# OppD                                              0.0162      0.037      0.441      0.659      -0.056       0.088
# ==============================================================================
# Omnibus:                       65.187   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.649
# Skew:                           0.012   Prob(JB):                     5.06e-18
# Kurtosis:                       3.223   Cond. No.                     1.66e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.66e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
pvals = est2.pvalues.to_frame('p_val').reset_index().rename(columns = {'index':'coef'})
pvals['p_val'] = round(pvals.p_val,3)
sig_vars = pvals[pvals.p_val <= 0.05]['coef'].tolist()
sig_vars.append("spread")
df_points = df_points[sig_vars]
X = df_points.drop('spread',axis = 1)
y = df_points.spread
X_train,X_test,y_train,y_test = train_test_split(X,y)
spread_cols = X_train.columns.tolist()
X_train.sample(5)
# Out:
#        simple_rating_system  opp_simple_rating_system  home
# 5178                   3.81                     -8.62     1
# 35234                 -3.48                     -7.75     0
# 46558                -11.15                     12.88     0
# 40163                 -3.49                      5.33     0
# 20051                -12.22                     -8.42     0

# %%
pf_reg = LinearRegression(n_jobs = -1)
pf_reg.fit(X_train,y_train)
print('Training:',pf_reg.score(X_train,y_train),mean_squared_error(y_train,pf_reg.predict(X_train),squared = False))
print('Testing:',pf_reg.score(X_test,y_test),mean_squared_error(y_test,pf_reg.predict(X_test),squared = False))
# Out:
# Training: 0.5111185391082598 10.18557243382938
# Testing: 0.5068644683982028 10.280112112881145

# %%
team_1 = 'Illinois'
team_2 = 'Purdue'
home_team = team_1
away_team = team_2
if team_1 in df_agg.name.unique().tolist():
    if team_2 in df_agg.name.unique().tolist():
        temp_df_2 = df_agg.loc[df_agg.name == team_1].loc[:,df_agg.columns[df_agg.columns.str.contains('percen') | df_agg.columns.str.contains('rat') | (df_agg.columns == 'pace') | (df_agg.columns == 'name')]]
        temp_df_3 = df_agg.loc[df_agg.name == team_2].loc[:,df_agg.columns[df_agg.columns.str.contains('percen') | df_agg.columns.str.contains('rat') | (df_agg.columns == 'pace') | (df_agg.columns == 'name')]]
        old_names = temp_df_2.columns[temp_df_2.columns.str.contains('opp_')].to_list()
        new_names = [i.replace('opp','allowed') for i in temp_df_2.columns[temp_df_2.columns.str.contains('opp_')].to_list()]
        name_dict = dict(zip(old_names,new_names))
        temp_df_2_dict = temp_df_2.rename(columns = name_dict).to_dict(orient = 'list')
        temp_df_2_dict.update(temp_df_3.iloc[0,:10].rename(dict(zip(temp_df_3.iloc[0,:10].index,['opp_'+str(i) for i in temp_df_3.iloc[0,:10].index]))).to_frame().transpose().to_dict(orient = 'list'))
        temp_df_2_dict.update(temp_df_3.iloc[0,25:].rename(dict(zip(temp_df_3.iloc[0,25:].index,['opp_'+str(i) for i in temp_df_3.iloc[0,25:].index]))).to_frame().transpose().to_dict(orient = 'list'))
        temp_df_2_dict.update(temp_df_3.iloc[0,10:25].rename(dict(zip(temp_df_3.iloc[0,10:25].index,[i + "_allowed" for i in temp_df_3.iloc[0,10:25].index]))).to_frame().transpose().to_dict(orient = 'list'))
        temp_df_3_dict = temp_df_3.rename(columns = name_dict).to_dict(orient = 'list')
        temp_df_3_dict.update(temp_df_2.iloc[0,:10].rename(dict(zip(temp_df_2.iloc[0,:10].index,['opp_'+str(i) for i in temp_df_2.iloc[0,:10].index]))).to_frame().transpose().to_dict(orient = 'list'))
        temp_df_3_dict.update(temp_df_2.iloc[0,25:].rename(dict(zip(temp_df_2.iloc[0,25:].index,['opp_'+str(i) for i in temp_df_2.iloc[0,25:].index]))).to_frame().transpose().to_dict(orient = 'list'))
        temp_df_3_dict.update(temp_df_2.iloc[0,10:25].rename(dict(zip(temp_df_2.iloc[0,10:25].index,[i + "_allowed" for i in temp_df_2.iloc[0,10:25].index]))).to_frame().transpose().to_dict(orient = 'list'))
        for i in temp_df_3_dict.keys():
            temp_df_2_dict[i]+=(temp_df_3_dict[i])
        master_dict = {key:[] for key in temp_df_2_dict.keys()}

        for i in temp_df_2_dict.keys():
            master_dict[i] += temp_df_2_dict[i]
        df_pred = pd.DataFrame.from_dict(master_dict)
        df_pred = df_pred[df_pred.name == home_team]
        df_pred['home'] = 1
        for i in df_pred.loc[:,df_pred.columns[df_pred.columns.str.contains('percent')]].columns:
             if df_pred[i].max() > 1:
                df_pred[i] = [j/100 for j in df_pred[i]]
df_pred = pd.merge(df_pred,kp_df2,left_on = 'name',right_on = "Team",how = 'left').drop("Team",axis = 1)
df_wl = df_pred[wl_cols]

loss_prob = clf.predict_proba(df_wl)[0][0]
win_prob = clf.predict_proba(df_wl)[0][1]

if win_prob >= loss_prob:
    print(home_team + ' has a ' + str(round(win_prob*100,2)) + '% chance of winning at home against ' +away_team)
else:
    print(away_team + ' has a ' + str(round(loss_prob*100,2)) + '% chance of winning on the road against ' + home_team)
    
df_spread = df_pred[spread_cols]
predicted_spread = int(round(pf_reg.predict(df_spread)[0]))
print("Predicted Spread is {}".format(predicted_spread))
# Out:
# Illinois has a 59.54% chance of winning at home against Purdue
# Predicted Spread is 1
